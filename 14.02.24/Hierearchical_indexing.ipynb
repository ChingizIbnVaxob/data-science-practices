# %% [markdown]
# <a href="https://colab.research.google.com/github/ChingizIbnVaxob/data-science-practices/blob/main/14.02.24/Hierearchical_indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # `Hierarchical indexing`

# %%
data = pd.Series(np.random.randn(9), index=['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'])

# %%
data
# Out:
# a   -1.300483
# a    0.647096
# a   -0.858512
# b   -2.020509
# b   -0.545594
# c    1.266214
# c   -0.580996
# d    0.858203
# d   -0.664723
# dtype: float64

# %%
data1 = pd.Series(np.random.randn(9),
                 index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'], [1, 2, 3, 1, 3, 1, 2, 2, 3]])
data1
# Out:
# a  1    0.273372
#    2    0.761303
#    3    0.885088
# b  1   -1.859893
#    3   -0.071226
# c  1    1.153153
#    2    0.448278
# d  2   -0.293029
#    3   -1.368813
# dtype: float64

# %% [markdown]
# **Ma'lumotlarni ajratib olish**

# %%
data1['a'][2]
# Out:
# 0.761303446280734

# %%
data1['c':'d']
# Out:
# c  1    1.153153
#    2    0.448278
# d  2   -0.293029
#    3   -1.368813
# dtype: float64

# %%
data1.loc[:, 2] # barcha 2- indekslardagi qiymatlarni ajratib olish
# Out:
# a    0.761303
# c    0.448278
# d   -0.293029
# dtype: float64

# %%
data1.loc[['b', 'd']]
# Out:
# b  1   -1.859893
#    3   -0.071226
# d  2   -0.293029
#    3   -1.368813
# dtype: float64

# %% [markdown]
# # .stack and .unstack    (sochish va yig'ish)

# %%
data1
# Out:
# a  1    0.273372
#    2    0.761303
#    3    0.885088
# b  1   -1.859893
#    3   -0.071226
# c  1    1.153153
#    2    0.448278
# d  2   -0.293029
#    3   -1.368813
# dtype: float64

# %%
data1.unstack() # sochilgan Ser ni DF ko'rinshida qaytaradi
# Out:
#           1         2         3
# a  0.273372  0.761303  0.885088
# b -1.859893       NaN -0.071226
# c  1.153153  0.448278       NaN
# d       NaN -0.293029 -1.368813

# %%
xxx = data1.unstack()


xxx.stack() # DFni yig'ilgan SEr ga aylantiradi.
# Out:
# a  1    0.273372
#    2    0.761303
#    3    0.885088
# b  1   -1.859893
#    3   -0.071226
# c  1    1.153153
#    2    0.448278
# d  2   -0.293029
#    3   -1.368813
# dtype: float64

# %% [markdown]
# ###################### Practise ##############################

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# fatal: destination path 'Practicum_Datasets' already exists and is not an empty directory.

# %%
df = pd.read_csv("/content/Practicum_Datasets/world_cities_air_water_quality.csv")
df
# Out:
#                   City                 "Region"                    "Country"  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#        "AirQuality"   "WaterPollution"
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3963 entries, 0 to 3962
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3963 non-null   object
#  1    "Region"          3963 non-null   object
#  2    "Country"         3963 non-null   object
#  3    "AirQuality"      3963 non-null   float64
#  4    "WaterPollution"  3963 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 154.9+ KB

# %%
columns = ['City', 'Region', 'Country', 'AirQuality', 'WaterPollution']
df.columns = columns
df
# Out:
#                   City                   Region                      Country  \
# 0        New York City               "New York"   "United States of America"
# 1     Washington, D.C.   "District of Columbia"   "United States of America"
# 2        San Francisco             "California"   "United States of America"
# 3               Berlin                       ""                    "Germany"
# 4          Los Angeles             "California"   "United States of America"
# ...                ...                      ...                          ...
# 3958             Yanbu        "Medina Province"               "Saudi Arabia"
# 3959           Cordoba              "Andalusia"                      "Spain"
# 3960               Vic              "Catalonia"                      "Spain"
# 3961           Segovia       "Castile and Leon"                      "Spain"
# 3962       Zamora city       "Castile and Leon"                      "Spain"
#
#       AirQuality  WaterPollution
# ...

# %%
df['Region'] = df['Region'].map(lambda x: x.replace('"', ""))
df
# Out:
#                   City                 Region                      Country  \
# 0        New York City               New York   "United States of America"
# 1     Washington, D.C.   District of Columbia   "United States of America"
# 2        San Francisco             California   "United States of America"
# 3               Berlin                                           "Germany"
# 4          Los Angeles             California   "United States of America"
# ...                ...                    ...                          ...
# 3958             Yanbu        Medina Province               "Saudi Arabia"
# 3959           Cordoba              Andalusia                      "Spain"
# 3960               Vic              Catalonia                      "Spain"
# 3961           Segovia       Castile and Leon                      "Spain"
# 3962       Zamora city       Castile and Leon                      "Spain"
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df['Country'] = df['Country'].map(lambda x: x.replace('"', ""))
df
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df
# Out:
#                   City                 Region                    Country  \
# 0        New York City               New York   United States of America
# 1     Washington, D.C.   District of Columbia   United States of America
# 2        San Francisco             California   United States of America
# 3               Berlin                                           Germany
# 4          Los Angeles             California   United States of America
# ...                ...                    ...                        ...
# 3958             Yanbu        Medina Province               Saudi Arabia
# 3959           Cordoba              Andalusia                      Spain
# 3960               Vic              Catalonia                      Spain
# 3961           Segovia       Castile and Leon                      Spain
# 3962       Zamora city       Castile and Leon                      Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# ...

# %%
df.to_csv("Updated_dataset.csv", index=False)

# %%
df[df['Country']=='Germany']
# Out:
# Empty DataFrame
# Columns: [City, Region, Country, AirQuality, WaterPollution]
# Index: []

# %%
df['Country'][2]
# Out:
# ' United States of America'

# %%
df['Country'] = df['Country'].map(lambda x: x.strip())
df
# Out:
#                   City                 Region                   Country  \
# 0        New York City               New York  United States of America
# 1     Washington, D.C.   District of Columbia  United States of America
# 2        San Francisco             California  United States of America
# 3               Berlin                                          Germany
# 4          Los Angeles             California  United States of America
# ...                ...                    ...                       ...
# 3958             Yanbu        Medina Province              Saudi Arabia
# 3959           Cordoba              Andalusia                     Spain
# 3960               Vic              Catalonia                     Spain
# 3961           Segovia       Castile and Leon                     Spain
# 3962       Zamora city       Castile and Leon                     Spain
#
#       AirQuality  WaterPollution
# 0      46.816038       49.504950
# 1      66.129032       49.107143
# ...

# %%
df[df['Country']=='Uzbekistan']
# Out:
#         City Region     Country  AirQuality  WaterPollution
# 21  Tashkent         Uzbekistan   56.451613       49.166667

# %% [markdown]
# pivot_table orqali irarxik indekslash

# %%
df1 = df.pivot_table(df, index = ['Country', 'City'])
df1.index
# Out:
# <ipython-input-131-b749a569647f>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df1 = df.pivot_table(df, index = ['Country', 'City'])
# MultiIndex([('Afghanistan',        'Andkhoy'),
#             ('Afghanistan',          'Farah'),
#             ('Afghanistan',          'Herat'),
#             ('Afghanistan',          'Kabul'),
#             ('Afghanistan',       'Kandahar'),
#             ('Afghanistan', 'Mazar-i-Sharif'),
#             (    'Albania',         'Ballsh'),
#             (    'Albania',         'Burrel'),
#             (    'Albania',         'Durres'),
#             (    'Albania',        'Elbasan'),
#             ...
#             (      'Yemen',          'Sanaa'),
#             (      'Yemen',         'Ta'izz'),
#             (     'Zambia',       'Chingola'),
#             (     'Zambia',          'Kitwe'),
# ...

# %%
df1.loc['Uzbekistan']
# Out:
#           AirQuality  WaterPollution
# City
# Tashkent   56.451613       49.166667

# %%
df1.loc[['Germany', 'Uzbekistan', 'Tajikistan']]
# Out:
#                               AirQuality  WaterPollution
# Country    City
# Germany    Aachen              70.454545       17.857143
#            Aalen               87.500000       50.000000
#            Abensberg          100.000000       50.000000
#            Amberg             100.000000       50.000000
#            Annaberg-Buchholz   87.500000       50.000000
# ...                                  ...             ...
#            Worms               60.000000      100.000000
#            Wuppertal           90.000000        0.000000
#            Zwickau             75.000000       50.000000
# Uzbekistan Tashkent            56.451613       49.166667
# Tajikistan Dushanbe            41.666667       61.111111
#
# [126 rows x 2 columns]

# %%
df2  = df1.copy()
df2
# Out:
#                       AirQuality  WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000
#             Farah     100.000000        0.000000
#             Herat      43.750000       31.250000
#             Kabul      18.421053       81.060606
#             Kandahar    0.000000       75.000000
# ...                          ...             ...
# Zambia      Mansa      75.000000       25.000000
# Zimbabwe    Bindura    50.000000       75.000000
#             Bulawayo   67.857143       71.428571
#             Harare     38.461538       87.500000
#             Masvingo   25.000000       62.500000
#
# [3895 rows x 2 columns]

# %%
df2['AirPollituion'] = 100-df2['AirQuality']
df2
# Out:
#                       AirQuality  WaterPollution  AirPollituion
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000      50.000000
#             Farah     100.000000        0.000000       0.000000
#             Herat      43.750000       31.250000      56.250000
#             Kabul      18.421053       81.060606      81.578947
#             Kandahar    0.000000       75.000000     100.000000
# ...                          ...             ...            ...
# Zambia      Mansa      75.000000       25.000000      25.000000
# Zimbabwe    Bindura    50.000000       75.000000      50.000000
#             Bulawayo   67.857143       71.428571      32.142857
#             Harare     38.461538       87.500000      61.538462
#             Masvingo   25.000000       62.500000      75.000000
#
# [3895 rows x 3 columns]

# %%
df2['WaterQuality'] = 100 - df2['WaterPollution']
df2
# Out:
#                       AirQuality  WaterPollution  AirPollituion  WaterQuality
# Country     City
# Afghanistan Andkhoy    50.000000       50.000000      50.000000     50.000000
#             Farah     100.000000        0.000000       0.000000    100.000000
#             Herat      43.750000       31.250000      56.250000     68.750000
#             Kabul      18.421053       81.060606      81.578947     18.939394
#             Kandahar    0.000000       75.000000     100.000000     25.000000
# ...                          ...             ...            ...           ...
# Zambia      Mansa      75.000000       25.000000      25.000000     75.000000
# Zimbabwe    Bindura    50.000000       75.000000      50.000000     25.000000
#             Bulawayo   67.857143       71.428571      32.142857     28.571429
#             Harare     38.461538       87.500000      61.538462     12.500000
#             Masvingo   25.000000       62.500000      75.000000     37.500000
#
# ...

# %%
df3 = pd.DataFrame(df2.values, index = df2.index, columns = [['AIR', 'AIR', 'WATER', 'WATER'], ['AirQuality', 'AirPollution', 'WaterQuality', 'WaterPollution']])
df3
# Out:
#                              AIR                     WATER
#                       AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000    50.000000      50.000000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Kandahar    0.000000    75.000000   100.000000      25.000000
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# Zimbabwe    Bindura    50.000000    75.000000    50.000000      25.000000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Masvingo   25.000000    62.500000    75.000000      37.500000
#
# ...

# %%
df3.columns.names = ['Object', 'Info']
df3
# Out:
# Object                       AIR                     WATER
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000    50.000000      50.000000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Kandahar    0.000000    75.000000   100.000000      25.000000
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# Zimbabwe    Bindura    50.000000    75.000000    50.000000      25.000000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Masvingo   25.000000    62.500000    75.000000      37.500000
#
# ...

# %%
df3.index.names
# Out:
# FrozenList(['Country', 'City'])

# %% [markdown]
# # Qayta tartiblash

# %%
df3
# Out:
# Object                       AIR                     WATER
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Afghanistan Andkhoy    50.000000    50.000000    50.000000      50.000000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Kandahar    0.000000    75.000000   100.000000      25.000000
# ...                          ...          ...          ...            ...
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# Zimbabwe    Bindura    50.000000    75.000000    50.000000      25.000000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Masvingo   25.000000    62.500000    75.000000      37.500000
#
# ...

# %% [markdown]
# # `swaplevel`

# %%
df3.swaplevel('Country', 'City')    # irarxik indekslarni o'rnini almashtirish
# Out:
# Object                       AIR                     WATER
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# City     Country
# Andkhoy  Afghanistan   50.000000    50.000000    50.000000      50.000000
# Farah    Afghanistan  100.000000     0.000000     0.000000     100.000000
# Herat    Afghanistan   43.750000    31.250000    56.250000      68.750000
# Kabul    Afghanistan   18.421053    81.060606    81.578947      18.939394
# Kandahar Afghanistan    0.000000    75.000000   100.000000      25.000000
# ...                          ...          ...          ...            ...
# Mansa    Zambia        75.000000    25.000000    25.000000      75.000000
# Bindura  Zimbabwe      50.000000    75.000000    50.000000      25.000000
# Bulawayo Zimbabwe      67.857143    71.428571    32.142857      28.571429
# Harare   Zimbabwe      38.461538    87.500000    61.538462      12.500000
# Masvingo Zimbabwe      25.000000    62.500000    75.000000      37.500000
#
# ...

# %% [markdown]
# # `sort_index`

# %%
df3.sort_index(level=0, ascending=False)
# Out:
# Object                       AIR                     WATER
# Info                  AirQuality AirPollution WaterQuality WaterPollution
# Country     City
# Zimbabwe    Masvingo   25.000000    62.500000    75.000000      37.500000
#             Harare     38.461538    87.500000    61.538462      12.500000
#             Bulawayo   67.857143    71.428571    32.142857      28.571429
#             Bindura    50.000000    75.000000    50.000000      25.000000
# Zambia      Mansa      75.000000    25.000000    25.000000      75.000000
# ...                          ...          ...          ...            ...
# Afghanistan Kandahar    0.000000    75.000000   100.000000      25.000000
#             Kabul      18.421053    81.060606    81.578947      18.939394
#             Herat      43.750000    31.250000    56.250000      68.750000
#             Farah     100.000000     0.000000     0.000000     100.000000
#             Andkhoy    50.000000    50.000000    50.000000      50.000000
#
# ...

# %% [markdown]
# # `.merge()   .join()`
#
#
#
# 1.   Merging
# 2.   Joining
# 3.   Concatenating
# 4.   Appening

# %%
# !git clone https://github.com/MansurCompAI/Practicum_Datasets.git
# Out:
# fatal: destination path 'Practicum_Datasets' already exists and is not an empty directory.

# %%
movies  = pd.read_csv('/content/Practicum_Datasets/IMDb/IMDb_movies.csv')
movies.info()
# Out:
# <ipython-input-146-161c5c431f54>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies  = pd.read_csv('/content/Practicum_Datasets/IMDb/IMDb_movies.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   imdb_title_id       85855 non-null  object
#  1   title               85855 non-null  object
#  2   original_title      85855 non-null  object
#  3   year                85855 non-null  object
#  4   date_published      85855 non-null  object
#  5   genre               85855 non-null  object
#  6   duration            85855 non-null  int64
#  7   country             85791 non-null  object
#  8   language            85022 non-null  object
#  9   director            85768 non-null  object
#  10  writer              84283 non-null  object
# ...

# %%
movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  \
# ...

# %%
ratings = pd.read_csv("/content/Practicum_Datasets/IMDb/IMDb_ratings.csv")

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   weighted_average_vote  85855 non-null  float64
#  2   total_votes            85855 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.0+ MB

# %%
pd.merge?

# %%
movies.merge(ratings).head(4)
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
#
#    year date_published                    genre  duration           country  \
# 0  1894     1894-10-09                  Romance        45               USA
# 1  1906     1906-12-26  Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                    Drama        53  Germany, Denmark
# 3  1912     1912-11-13           Drama, History       100               USA
#
#   language            director                                 writer  \
# 0     None     Alexander Black                        Alexander Black
# 1     None        Charles Tait                           Charles Tait
# ...

# %%
movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  \
# ...

# %%
ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes
# 0     tt0000009                    5.9          154
# 1     tt0000574                    6.1          589
# 2     tt0001892                    5.8          188
# 3     tt0002101                    5.2          446
# 4     tt0002130                    7.0         2237

# %%
movies_ratings = pd.merge(movies, ratings)
movies_ratings.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  \
# ...

# %%
movies_ratings.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'budget',
#        'weighted_average_vote', 'total_votes'],
#       dtype='object')

# %%
extracted = movies_ratings[['title', 'year', 'weighted_average_vote', 'total_votes']]
extracted
# Out:
#                                 title  year  weighted_average_vote  \
# 0                          Miss Jerry  1894                    5.9
# 1         The Story of the Kelly Gang  1906                    6.1
# 2                      Den sorte drøm  1911                    5.8
# 3                           Cleopatra  1912                    5.2
# 4                           L'Inferno  1911                    7.0
# ...                               ...   ...                    ...
# 85850                         Le lion  2020                    5.3
# 85851  De Beentjes van Sint-Hildegard  2020                    7.7
# 85852       Padmavyuhathile Abhimanyu  2019                    7.9
# 85853               Sokagin Çocuklari  2019                    6.4
# 85854      La vida sense la Sara Amat  2019                    6.7
#
#        total_votes
# 0              154
# 1              589
# 2              188
# 3              446
# 4             2237
# ...            ...
# ...
