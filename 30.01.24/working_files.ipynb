# %% [markdown]
# <a href="https://colab.research.google.com/github/ChingizIbnVaxob/data-science-practices/blob/main/30.01.24/working_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data.csv
# Out:
# --2024-01-30 04:26:49--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3146 (3.1K) [text/plain]
# Saving to: ‘automobile_data.csv.1’
#
# automobile_data.csv 100%[===================>]   3.07K  --.-KB/s    in 0s
#
# 2024-01-30 04:26:49 (35.6 MB/s) - ‘automobile_data.csv.1’ saved [3146/3146]

# %%
! git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# Cloning into 'praktikum_datasets'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 145 (delta 46), reused 44 (delta 43), pack-reused 93
# Receiving objects: 100% (145/145), 9.72 MiB | 13.10 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
df  = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df = pd.read_excel('uzbekistan.xlsx', index_col=0, names=['hudud', 'maydon', 'aholi'])
df
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
pd.read_csv('automobile_data.csv', index_col='index',  nrows=15)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
# 13             bmw        sedan       103.5   189.0         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# ...

# %%
df.to_csv("newuzb.csv")

# %%
df
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
obj = df.maydon
obj
# Out:
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydon, dtype: int64

# %%
obj.to_csv("uzmaydon.csv")

# %%
pd.read_csv('uzmaydon.csv', index_col= 'hudud', squeeze=True)
# Out:
# <ipython-input-18-b2dbd780ffc6>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   pd.read_csv('uzmaydon.csv', index_col= 'hudud', squeeze=True)
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydon, dtype: int64

# %%
df2 = pd.read_csv('automobile_data.csv', index_col=0)
df2
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
df2.to_excel("drive/MyDrive/newcars.xlsx", index=False, columns=['company', 'body-style', 'price'])
df2
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-80f39da78526> in <cell line: 1>()
# ----> 1 df2.to_excel("drive/MyDrive/newcars.xlsx", index=False, columns=['company', 'body-style', 'price'])
#       2 df2
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ...

# %% [markdown]
# # HDF5  format

# %%
hdfobj = pd.HDFStore("data.h5")

# %%
hdfobj.put("uzdata", df)

# %%
hdfobj.put("cardata", df2)

# %%
hdfobj.keys()
# Out:
# ['/cardata', '/uzdata']

# %%
hdfobj['uzdata']
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
hdfobj['cardata']
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
hdfobj.close()

# %%
hdfobj = pd.HDFStore("data.h5")

# %%
hdfobj.close()

# %%
data = pd.read_hdf("data.h5", key="uzdata")

# %%
#!fuser -k data.h5

# %%
data.to_hdf('data.h5', key="uzdata")

# %% [markdown]
# # Web sahifalardan o'qish

# %%
tashkent = pd.read_html('https://en.wikipedia.org/wiki/Tashkent')

# %%
len(tashkent)
# Out:
# 19

# %%
tashkent[0]
# Out:
#                             Tashkent  ТошкентToshkent  \
# 0                                        Capital city
# 1   .mw-parser-output .tmulti .multiimageinner{dis...
# 2   .mw-parser-output .ib-settlement-cols{text-ali...
# 3                             Nickname: Tash (A rock)
# 4   Motto(s): Kuch Adolatdadir! ("Strength is in J...
# 5                  Location of Tashkent in Uzbekistan
# 6   .mw-parser-output .locmap .od{position:absolut...
# 7   Coordinates: .mw-parser-output .geo-default,.m...
# 8                                             Country
# 9                                             Settled
# 10                                          Divisions
# 11                                         Government
# 12                                             • Type
# 13                                    • Hakim (Mayor)
# 14                                               Area
# 15                                     • Capital city
# ...

# %%
tashkent[5]
# Out:
#    Climate data for Tashkent (1991–2020, extremes 1867–present)  \
#                                                           Month
# 0                                 Record high °C (°F)
# 1                          Mean daily maximum °C (°F)
# 2                                  Daily mean °C (°F)
# 3                          Mean daily minimum °C (°F)
# 4                                  Record low °C (°F)
# 5                   Average precipitation mm (inches)
# 6              Average extreme snow depth cm (inches)
# 7                                  Average rainy days
# 8                                  Average snowy days
# 9                       Average relative humidity (%)
# 10                        Mean monthly sunshine hours
# 11                        Source 1: Pogoda.ru.net[53]
# 12                                 Source 2: NOAA[54]
#
#                                                               \
#                             Jan                          Feb
# ...

# %% [markdown]
# # JSON

# %%
pd.read_json("prize.json")
# Out:
#                                                 prizes
# 0    {'year': '2023', 'category': 'chemistry', 'lau...
# 1    {'year': '2023', 'category': 'economics', 'lau...
# 2    {'year': '2023', 'category': 'literature', 'la...
# 3    {'year': '2023', 'category': 'peace', 'laureat...
# 4    {'year': '2023', 'category': 'physics', 'laure...
# ..                                                 ...
# 665  {'year': '1901', 'category': 'chemistry', 'lau...
# 666  {'year': '1901', 'category': 'literature', 'la...
# 667  {'year': '1901', 'category': 'peace', 'laureat...
# 668  {'year': '1901', 'category': 'physics', 'laure...
# 669  {'year': '1901', 'category': 'medicine', 'laur...
#
# [670 rows x 1 columns]

# %%
import requests
r = requests.get("https://openlibrary.org/subjects/python.json?published_in=2010-2023")

# %%
pd.DataFrame(r.json()['works'])

# %%
import requests, json
r = requests.get('http://api.nobelprize.org/v1/laureate.json')
data = r.json()
# data['laureates']
pd.DataFrame(data['laureates'],)
# Out:
#        id       firstname    surname        born        died  \
# 0       1  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10
# 1       2      Hendrik A.    Lorentz  1853-07-18  1928-02-04
# 2       3          Pieter     Zeeman  1865-05-25  1943-10-09
# 3       4           Henri  Becquerel  1852-12-15  1908-08-25
# 4       5          Pierre      Curie  1859-05-15  1906-04-19
# ..    ...             ...        ...         ...         ...
# 987  1030           Louis       Brus  1943-00-00  0000-00-00
# 988  1031         Aleksey    Yekimov  1945-00-00  0000-00-00
# 989  1032             Jon      Fosse  1959-09-29  0000-00-00
# 990  1033          Narges  Mohammadi  1972-04-21  0000-00-00
# 991  1034         Claudia     Goldin  1946-00-00  0000-00-00
#
#                bornCountry bornCountryCode                        bornCity  \
# 0    Prussia (now Germany)              DE          Lennep (now Remscheid)
# 1          the Netherlands              NL                          Arnhem
# ...

# %% [markdown]
# # API

# %%
cats = requests.get("https://cat-fact.herokuapp.com")

# %%
cats.json
# Out:
# <Response [200]>

# %%
import requests

# Where USD is the base currency you want to use
url = 'https://v6.exchangerate-api.com/v6/79370a1733e6bc08cec2fcd5/latest/USD'

# Making our request
response = requests.get(url)
data = response.json()

# Your JSON object
print(data['conversion_rates']['UZS'])
print(data['time_last_update_utc'])
# Out:
# 12354.7016
# Tue, 30 Jan 2024 00:00:01 +0000

# %%
import pandas as pd
data = pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %%
len(data)
# Out:
# 19

# %%
data[5]
# Out:
#    Climate data for Tashkent (1991–2020, extremes 1867–present)  \
#                                                           Month
# 0                                 Record high °C (°F)
# 1                          Mean daily maximum °C (°F)
# 2                                  Daily mean °C (°F)
# 3                          Mean daily minimum °C (°F)
# 4                                  Record low °C (°F)
# 5                   Average precipitation mm (inches)
# 6              Average extreme snow depth cm (inches)
# 7                                  Average rainy days
# 8                                  Average snowy days
# 9                       Average relative humidity (%)
# 10                        Mean monthly sunshine hours
# 11                        Source 1: Pogoda.ru.net[53]
# 12                                 Source 2: NOAA[54]
#
#                                                               \
#                             Jan                          Feb
# ...

# %%
data[7]
# Out:
#     Year     Pop. ±% p.a.
# 0   1897   155673       —
# 1   1959   911930  +2.89%
# 2   1970  1384509  +3.87%
# 3   1979  1780002  +2.83%
# 4   1983  1902000  +1.67%
# 5   1989  2072459  +1.44%
# 6   1991  2130200  +1.38%
# 7   1995  2097400  −0.39%
# 8   2000  2142300  +0.42%
# 9   2001  2137900  −0.21%
# 10  2002  2136600  −0.06%
# 11  2003  2139200  +0.12%
# 12  2004  2135400  −0.18%
# 13  2005  2135700  +0.01%
# 14  2006  2140600  +0.23%
